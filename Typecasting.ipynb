# %%
#Type casting- is a process of converting one variable into another variable
name="Avinash"
age=31
gpa=6.2
is_student=True

#first get the data types of each variable-- this we can acheive using the type function
print(type(name))
print(type(age))
print(type(gpa))
print(type(is_student))

#now perform type casting
#convert float into intiger using type casting
ngpa=int(gpa)

#convert integer into float using typecasting
nage=float(age)

#convert string into boolean
nname=bool(name)
#convert boolean to string
nis_student=str(is_student)
print(nis_student)
#convert boolean to int
ois_student=int(is_student)
print(ois_student)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# True
# 1
