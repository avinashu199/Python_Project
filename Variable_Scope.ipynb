# %%
'''
Varibale is having scope by which the output values are displayed/itenfied
sequence of priority for values are 
(L>E>G>B)Local>Enclosed>Global>Buitin
based on the priority values will be displayed and understood by the python
'''

# %%
#Local Variables-- these are varibales with in a functions and their validity is within that specific function only
#2 functions with 2 different local variables
def dad():
    name="Avinash" #This is a local varible
    print(name)
def mom():
    naam="Kavita" #This is a local varible
    print(naam)
dad()
mom()
# Out:
# Avinash
# Kavita

# %%
#same above program where we are replacing the variable of one function with another function to see the results
#because local variables are specific to those functions,python will throw an error
def dad():
    name="Avinash" #This is a local varible
    print(naam)
def mom():
    naam="Kavita" #This is a local varible
    print(name)
dad()
mom()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       7     naam="Kavita" #This is a local varible
#       8     print(name)
# ----> 9 dad()
#      10 mom()
#
# Cell In[2], line 5, in dad()
#       3 def dad():
#       4     name="Avinash" #This is a local varible
# ----> 5     print(naam)
#
# NameError: name 'naam' is not defined

# %%
#enclosed variables are the varibales defined in functions that are enclosed in the same function
def family():
    name="Uppalapati" #This is an enclosed varible
    def dad():
        #name="Avinash" #THis is a local variable 
        print(name)
    dad()
family()
# Out:
# Uppalapati

# %%
#Global variables- these are varibales that are declared outside of the range of the function and also not in any other enclosed function
name="Avinash Uppalapati"
def family():
    name="Ayaansh"
    print(name)
family()
# Out:
# Ayaansh

# %%
#Build in variables-varibales that are defined in python built in modules 
from hero import movie
cinema=movie
def bms():
   # cinema="Spirit"
    print(cinema)
bms()
# Out:
# Bahubali
