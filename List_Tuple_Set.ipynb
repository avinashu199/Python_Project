# %%
'''
collection of variables/values can be acheived in python using list,tuple and set 
List:
List is represented using [].
inside list we can store multiple values
duplicates are allowed in the list
In list we can change/update the existing values
In list we can add and remove the values
Lot of methods are there which we can use in the list
'''

# %%
family=['RangaRaju','SrinivasaRaju','Avinash','Ayaansh','Kavita']
#List is ordered i.e all the details will be in the same order as we have inserted
#print(family)

#list we can access each element and we can update manually as well
#to access we can use the index position like in strings
#print(family[2])

#update the values of specific directly
#family[4]='Vedansh'
#print(family)

#we can use the concept of slicing in list as well
#print(family[::-2])
'''
Methods that are usefull which working around list
1.Index method(Like find method in the string methods)-We can get the index position of the certain element
2.Count method(same as count method in string)- It will count the total repitetations of certain values in the list
3.length method(same as length method in string)-Total length of the list
4.append method- we can add new values to the end of the list
5.remove method- we can remove specific element from the list
6.sorted method- sort the values of the list in alpha order or by ascending order
7.membership operator-
8.clear --- clear the 
'''
#we can get the index position of the value
#print(family.index('RangaRaju'))

#we can count the repetitions in the list using count method
#family=['RangaRaju','SrinivasaRaju','Avinash','Ayaansh','Kavita','Kavita']
#print(family.count('Kavita'))

#length method
#print(len(family))

#Append method
#family.append('Vedansh')
#print(family)

#Remove method
#family.remove('RangaRaju')
#print(family)

#sort
#result=sorted(family)
#print(result)

#reversed
#rev=reversed(result)
#print(list(rev))

#membership operator
#print('Advik' in family)

#clear the list
family.clear()
print(family)
# Out:
# []
