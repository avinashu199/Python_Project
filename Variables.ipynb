# %%
'''
Variables are like containers which can store different types of data

1) Data Types- Numeric,Text,Boolean
2) There are different naming convensions that need to be followed while creating the variables
3) We can also use the f string concept in print statement if we have varibles
'''

# %%
'''
2) Naming convensions- Variable name can be anything but we need to follow few rules
    a. Variable length can be anything
    b. Variable name should not contain any special characters(but it can start or contain _)
    c. spacing is not allowed, we can use _ instead of spacing
    d. Variable name should not start with integers
    
'''
name='Avinash'
print(name)

name123='Uppalapati'
print(name123)
'''
1name='Ayaansh' -- Syntax Error (Invalid decimal literal)
print(1name)
'''
'''
first name='Ranga Raju'-- invalid syntax
print(first name)
'''
'''
age%= 25-- invalid syntax
print(age%)
'''
# Out:
# Avinash
# Uppalapati
# '\nage%= 25-- invalid syntax\nprint(age%)\n'

# %%
#f string using variables in the print statement
name="Avinash"
age=31
city='Vijayawada'

print(f"My name is {name} and my age is {age} and current city is {city}")
# Out:
# My name is Avinash and my age is 31 and current city is Vijayawada

# %%
#Data types
#Numeric data types(Int,float & complex)- we can perform arthematic operations on these data types
age= 31 #Integer
distance= 5.5 #float
print(f"My age is {age} and today i have travelled {distance}km to reach office")
# Out:
# My age is 31 and today i have travelled 5.5km to reach office

# %%
#Boolean- will accept only 2 values, i.e True or False. we will use this mostly in the condition and looping statements
result= False
if result:
    print("Cleared my board exam successfully")
else:
    print("Failed my board exam")
# Out:
# Failed my board exam
