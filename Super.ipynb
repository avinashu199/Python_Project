# %%
'''
Super-- This is used to call the instance variables and methods of the parent class into the child classes.
We can use the super mostly to perform method overiding
'''

# %%
#Using super to extend the instance varibales of the parent class into the child class

class Dog:
    def __init__(self,color,legs,guardian,friendly):
        self.color=color
        self.legs=legs
class Tiger:
    def __init__(self,color,legs,hunter):
        self.color=color
        self.legs=legs
        self.hunter=hunter
class cat:
    def __init__(self,color,legs,friendly):
        self.color=color
        self.legs=legs
        self.friendly=friendly

# %%
'''
in the above pgm we have common attributed which are color,legs across all the classes, 
so we can create a parent class with those attributes we can inherit them and call them using super method manually
'''
class Main: #parent class
    def __init__(self,color,legs):
        self.color=color
        self.legs=legs
class Dog(Main):
    def __init__(self,color,legs,guardian,friendly):
        super().__init__(color,legs)
        self.guardian=guardian
        self.friendly=friendly
class Tiger(Main):
    def __init__(self,color,legs,hunter):
        super().__init__(color,legs)
        self.hunter=hunter
class cat(Main):
    def __init__(self,color,legs,friendly):
        super().__init__(color,legs)
        self.friendly=friendly

obj1=Dog(color='White',legs=4,guardian=True,friendly=True)
print(obj1.color)
print(obj1.legs)
print(obj1.guardian)
print(obj1.friendly)
# Out:
# White
# 4
# True
# True

# %%
'''
Use the same program but this time use it to method overriding using super() and also use it to call the methods of the parent class in the child class
'''
class Main: #parent class
    def eat(self): #Parent method
        print("Parent method: Eat")
class Dog(Main):
    def eat(self):#child method
        print("Dog method: eat")
        super().eat() #Calling the parent method using super so that parent eat also will be executed together
class Tiger(Main):
    def eat(self):#child method
        print("Tiger method: eat")
class Cat(Main):
    def eat(self):#child method
        print("Cat method: eat")

obj=Dog()
obj.eat()

#now using super we can override as well and also we can call the parent method in the child even when they have the same name
# Out:
# Dog method: eat
# Parent method: Eat
