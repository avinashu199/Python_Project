# %% [markdown]
# Writing a simple program in python using basic functionalities like comments & print

# %%
#First program -- we can use single line comments in python using hash tag
print("Learn coding in python")
# Out:
# Learn coding in python

# %%
print('Current version of python in the notebook is 3.12.7') #we can use '' in print statement
'''
by default after printing the text, cursor will point to the new line
'''
print("Current stable version of python in realword is 3.14-- release on october 7") #But it is recommended to use "" in the print statement
# Out:
# Current version of python in the notebook is 3.12.7
# Current stable version of python in realword is 3.14-- release on october 7

# %%
'''
if we want to get the text of the multiple statements in the same line then we can use end in the print statement as mentioned below
'''
print('India womens beat SA womens by 40 runs',end=' & ') #using the end we can avoid new line and get everything in the same line
print("India womens become the champions of 2025 world cup")
# Out:
# India womens beat SA womens by 40 runs & India womens become the champions of 2025 world cup
